# %%
# !pip install pyarrow -q

# %%
import pandas as pd

# %%
january_df = pd.read_parquet('yellow_tripdata_2023-01.parquet')

# %%
len(january_df.columns) # task 1. number of columns in january dataset
# Out:
# 19

# %%
january_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
january_df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %%
january_df['duration'] = january_df['tpep_dropoff_datetime'] - january_df['tpep_pickup_datetime']

# %%
january_df['minutes'] = january_df['duration'].dt.total_seconds() / 60

# %%
january_df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1               2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2               2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3               1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4               2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# ...           ...                  ...                   ...              ...
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
# ...

# %%
january_df['minutes'].std() # task 2. compute ride duration
# Out:
# 42.594351241920904

# %%
initial_list = january_df['minutes'].to_list()

# %%
initial_list_length = len(initial_list)

# %%
initial_list_length
# Out:
# 3066766

# %%
no_outliers_list = [stamp for stamp in initial_list if stamp >= 1 and stamp <= 60]

# %%
no_outliers_list_length = len(no_outliers_list)

# %%
no_outliers_list_length
# Out:
# 3009173

# %%
100 / initial_list_length * no_outliers_list_length # task 3. outliers removal
# Out:
# 98.12202822125978

# %% [markdown]
# ## Q4. One-hot encoding

# %%
january_df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1               2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2               2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3               1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4               2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# ...           ...                  ...                   ...              ...
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
# ...

# %%
categorical = ["PULocationID", "DOLocationID"]
numerical = ['trip_distance']

# %%
january_df[categorical].dtypes
# Out:
# PULocationID    int64
# DOLocationID    int64
# dtype: object

# %%
january_df[categorical] = january_df[categorical].astype(str)

# %%
january_df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1               2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2               2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3               1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4               2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# ...           ...                  ...                   ...              ...
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
# ...

# %%
january_df.dtypes
# Out:
# VendorID                           int64
# tpep_pickup_datetime      datetime64[ns]
# tpep_dropoff_datetime     datetime64[ns]
# passenger_count                  float64
# trip_distance                    float64
# RatecodeID                       float64
# store_and_fwd_flag                object
# PULocationID                      object
# DOLocationID                      object
# payment_type                       int64
# fare_amount                      float64
# extra                            float64
# mta_tax                          float64
# tip_amount                       float64
# tolls_amount                     float64
# improvement_surcharge            float64
# total_amount                     float64
# congestion_surcharge             float64
# airport_fee                      float64
# duration                 timedelta64[ns]
# minutes                          float64
# dtype: object

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
dv = DictVectorizer()

# %%
train_dicts = january_df[categorical + numerical].to_dict(orient="records")

# %%
X_train = dv.fit_transform(train_dicts)

# %%
X_train
# Out:
# <3066766x519 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9200298 stored elements in Compressed Sparse Row format>

# %%
X_train.get_shape()
# Out:
# (3066766, 519)

# %%
dv.feature_names_
# Out:
# ['DOLocationID=1',
#  'DOLocationID=10',
#  'DOLocationID=100',
#  'DOLocationID=101',
#  'DOLocationID=102',
#  'DOLocationID=105',
#  'DOLocationID=106',
#  'DOLocationID=107',
#  'DOLocationID=108',
#  'DOLocationID=109',
#  'DOLocationID=11',
#  'DOLocationID=111',
#  'DOLocationID=112',
#  'DOLocationID=113',
#  'DOLocationID=114',
#  'DOLocationID=115',
#  'DOLocationID=116',
#  'DOLocationID=117',
#  'DOLocationID=118',
#  'DOLocationID=119',
#  'DOLocationID=12',
#  'DOLocationID=120',
#  'DOLocationID=121',
#  'DOLocationID=122',
#  'DOLocationID=123',
#  'DOLocationID=124',
#  'DOLocationID=125',
#  'DOLocationID=126',
#  'DOLocationID=127',
#  'DOLocationID=128',
#  'DOLocationID=129',
#  'DOLocationID=13',
#  'DOLocationID=130',
#  'DOLocationID=131',
#  'DOLocationID=132',
#  'DOLocationID=133',
#  'DOLocationID=134',
#  'DOLocationID=135',
#  'DOLocationID=136',
#  'DOLocationID=137',
#  'DOLocationID=138',
#  'DOLocationID=139',
#  'DOLocationID=14',
# ...

# %%
target = 'duration'

# %%
y_train = january_df[target].values

# %%
y_train
# Out:
# array([ 506000000000,  379000000000,  765000000000, ..., 1471000000000,
#         780000000000,  864000000000], dtype='timedelta64[ns]')

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(y_pred, label="prediction")
sns.distplot(y_train, label="actual")

plt.legend()
# Out:
# /home/klychliiev/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/klychliiev/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_train, y_pred, squared=False)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Input In [69], in <cell line: 1>()
# ----> 1 mean_squared_error(y_train, y_pred, squared=False)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_regression.py:442, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     438 y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     439     y_true, y_pred, multioutput
#     440 )
#     441 check_consistent_length(y_true, y_pred, sample_weight)
# --> 442 output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#     444 if not squared:
#     445     output_errors = np.sqrt(output_errors)
#
# UFuncTypeError: ufunc 'subtract' cannot use operands with types dtype('<m8[ns]') and dtype('float64')

# %%
y_pred
# Out:
# array([7.59902512e+11, 7.56999979e+11, 7.60941034e+11, ...,
#        7.90894528e+11, 8.55586331e+11, 7.66566144e+11])
